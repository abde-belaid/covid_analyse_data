# %% [markdown]
# # Exploration des données Covid
#
# Ce notebook est un point de départ pour charger et visualiser les données avec PySpark.

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName('CovidDataExploration').getOrCreate()
print('Spark session prête')
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/30 12:50:53 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Spark session prête
